# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ### Weather Data Analysis
# * Of the four weather measures were examined against changes in latitude, and the strongest correlation (-0.91) was found between Northern Hemisphere latitudes versus temperature. This relationship had a high r-squared value of 0.81 meaning that   81% of the variance in this data could be explained by the equation of the line from linear regression.
# * As expected, as one approaches the equator the temperature the weather becomes significantly warmer, hence there is strong     correlation between max temerature and latitude.
# * Most interesting is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere.
# * There is very weak to no relationship between city latitudes and humidity, cloudiness and windspeed.
# * It is interesting to see that a strong band of cities sits at 0%, 80%, and 100% cloudiness.
#
# ####  there were some weak correlations relationships with their r-squared values
# * Northern Hemisphere - Temperature (F) vs. Latitude r-squared 0.81
# * Southern Hemisphere - Temperature (F) vs. Latitude r-squared 0.46
# * Northern Hemisphere - Humidity (%) vs. Latitude r-squared 0.05
# * Southern Hemisphere - Humidity (%) vs. Latitude r-squared 0.12
# * Northern Hemisphere - Cloudiness (%) vs. Latitude r-squared 0.005
# * Southern Hemisphere - Cloudiness (%) vs. Latitude r-squared 0.017
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude r-squared 0.051
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude r-squared 0.21
#
# #### Some observable trends based on this data:
#
# * Temperature decreases as you move north from the equator in the Northern Hemisphere in strongly linear fashion.
# * Temperature decreases as you move south from the equator in the Southern Hemisphere in a weak linear fashion.
# * In the Northern Hemisphere Humidity is very weakly correlated to increase as you increase in latitude.
# * In the Southern Hemisphere Humidity is very weakly correlated to decrease as you move south in latitude.
# * Cloudiness is not correlated to latitude in the Northern Hemisphere.
# * Cloudiness is very weakly correlated to decrease as you move south in latitude in the Southern Hemisphere.
# * Wind Speed is not correlated to latitude in the Northern Hemisphere, however in northern hemispheres there is a flurry of       cities  with over 20 mph of wind.
# * In the Southern Hemisphere, Wind Speed is weakly correlated to increase as you move south in latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import csv
from os import path
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# set figure size to 9x5
plt.rcParams['figure.figsize'] = [7, 5]

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities_count = len(cities)
print(cities_count)
# Out:
# 621

# %%
# print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url + api key 

#One City Test


params = {'q': 'London',
          'APPID': weather_api_key,
          'units': 'Imperial'}

base_url = 'http://api.openweathermap.org/data/2.5/weather?'
city_response = requests.get(base_url, params=params)

city_json = city_response.json()


#print(city_json['name'])
print(city_json['name'])
# Out:
# London

# %%
print(json.dumps(city_json, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.51,
#         "lon": -0.13
#     },
#     "dt": 1586653374,
#     "id": 2643743,
#     "main": {
#         "feels_like": 48.56,
#         "humidity": 58,
#         "pressure": 1019,
#         "temp": 53.58,
#         "temp_max": 59,
#         "temp_min": 48
#     },
#     "name": "London",
#     "rain": {
#         "3h": 0.76
#     },
#     "sys": {
#         "country": "GB",
#         "id": 1414,
#         "sunrise": 1586668217,
#         "sunset": 1586717501,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 4.7
#     }
# }

# %%
# retrieve city weather data and write to csv file

if path.exists("output_data/cities.csv"):
    print("cities.csv generated!")
else:
    with open(output_data_file, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=',')
        csvwriter.writerow(['City','Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed'])



print('Beginning Data Retrieval')
print('----------------------------------------------------------------------')
city_json = []
for city in cities:
    params = {'q': city,
             'APPID': weather_api_key,
             'units': 'imperial'}
    
    index = cities.index(city) + 1
    
    try:
        print('Processing City # {} | {}'.format(index, city))
        request = requests.get(base_url, params=params)
        city_json.append(request.json())
        
    except:
        print('City: {} not found. skipping.....................'.format(city))
print('------------------------------------------------------------------------')
print('Data Retrieval Complete')
# Out:
# cities.csv generated!
# Beginning Data Retrieval
# ----------------------------------------------------------------------
# Processing City # 1 | codrington
# Processing City # 2 | busselton
# Processing City # 3 | ponta do sol
# Processing City # 4 | taolanaro
# Processing City # 5 | rikitea
# Processing City # 6 | sakakah
# Processing City # 7 | asau
# Processing City # 8 | rastu
# Processing City # 9 | klaksvik
# Processing City # 10 | yellowknife
# Processing City # 11 | brae
# Processing City # 12 | kashary
# Processing City # 13 | tumannyy
# Processing City # 14 | atuona
# Processing City # 15 | saint george
# Processing City # 16 | cape town
# Processing City # 17 | san quintin
# Processing City # 18 | belushya guba
# Processing City # 19 | port alfred
# Processing City # 20 | half moon bay
# Processing City # 21 | odienne
# Processing City # 22 | mulatupo
# Processing City # 23 | muzquiz
# Processing City # 24 | albany
# Processing City # 25 | mys shmidta
# Processing City # 26 | cururupu
# Processing City # 27 | lebu
# Processing City # 28 | am timan
# Processing City # 29 | provideniya
# Processing City # 30 | amurzet
# Processing City # 31 | tsihombe
# Processing City # 32 | cidreira
# Processing City # 33 | port elizabeth
# Processing City # 34 | newport
# Processing City # 35 | ambilobe
# Processing City # 36 | walvis bay
# Processing City # 37 | queanbeyan
# Processing City # 38 | heihe
# Processing City # 39 | qaanaaq
# Processing City # 40 | mataura
# Processing City # 41 | longyearbyen
# Processing City # 42 | ikom
# Processing City # 43 | ostrovnoy
# Processing City # 44 | taltal
# Processing City # 45 | punta arenas
# Processing City # 46 | kupang
# Processing City # 47 | auras
# Processing City # 48 | uray
# Processing City # 49 | tasiilaq
# Processing City # 50 | butaritari
# Processing City # 51 | anapskaya
# Processing City # 52 | ayacucho
# Processing City # 53 | medea
# Processing City # 54 | bluff
# Processing City # 55 | borlange
# Processing City # 56 | dikson
# Processing City # 57 | georgetown
# Processing City # 58 | tambura
# Processing City # 59 | copala
# Processing City # 60 | hobart
# Processing City # 61 | sambava
# Processing City # 62 | salihorsk
# Processing City # 63 | pevek
# Processing City # 64 | sitka
# Processing City # 65 | jamestown
# Processing City # 66 | hithadhoo
# Processing City # 67 | pachino
# Processing City # 68 | san juan
# Processing City # 69 | ribeira grande
# Processing City # 70 | katha
# Processing City # 71 | barentsburg
# Processing City # 72 | san patricio
# Processing City # 73 | bethel
# Processing City # 74 | falealupo
# Processing City # 75 | pocatello
# Processing City # 76 | bredasdorp
# Processing City # 77 | srednekolymsk
# Processing City # 78 | seoul
# Processing City # 79 | nizhneyansk
# Processing City # 80 | puerto ayora
# Processing City # 81 | hilo
# Processing City # 82 | high level
# Processing City # 83 | guiberoua
# Processing City # 84 | hermanus
# Processing City # 85 | grootfontein
# Processing City # 86 | san-pedro
# Processing City # 87 | ushuaia
# Processing City # 88 | palmer
# Processing City # 89 | barrow
# Processing City # 90 | aswan
# Processing City # 91 | leningradskiy
# Processing City # 92 | pangnirtung
# Processing City # 93 | shache
# Processing City # 94 | areosa
# Processing City # 95 | beringovskiy
# Processing City # 96 | kapaa
# Processing City # 97 | aykhal
# Processing City # 98 | ha giang
# Processing City # 99 | durban
# Processing City # 100 | dehra dun
# Processing City # 101 | ahipara
# Processing City # 102 | lins
# Processing City # 103 | khudumelapye
# Processing City # 104 | guicheng
# Processing City # 105 | souillac
# Processing City # 106 | baruun-urt
# Processing City # 107 | inirida
# Processing City # 108 | aleksandrov gay
# Processing City # 109 | castro
# Processing City # 110 | vaini
# Processing City # 111 | waiuku
# Processing City # 112 | honiara
# Processing City # 113 | chuy
# Processing City # 114 | new norfolk
# Processing City # 115 | flagstaff
# Processing City # 116 | saskylakh
# Processing City # 117 | rajapur
# Processing City # 118 | wewak
# Processing City # 119 | el reno
# Processing City # 120 | we
# Processing City # 121 | thompson
# Processing City # 122 | jutai
# Processing City # 123 | buraydah
# Processing City # 124 | sol-iletsk
# Processing City # 125 | sept-iles
# Processing City # 126 | umba
# Processing City # 127 | fort walton beach
# Processing City # 128 | meadow lake
# Processing City # 129 | road town
# Processing City # 130 | la libertad
# Processing City # 131 | quatre cocos
# Processing City # 132 | laguna
# Processing City # 133 | preobrazheniye
# Processing City # 134 | avarua
# Processing City # 135 | ilulissat
# Processing City # 136 | novovasylivka
# Processing City # 137 | bilma
# Processing City # 138 | bira
# Processing City # 139 | ondangwa
# Processing City # 140 | ciudad bolivar
# Processing City # 141 | santa cruz de tenerife
# Processing City # 142 | sebinkarahisar
# Processing City # 143 | santa marta
# Processing City # 144 | auki
# Processing City # 145 | amderma
# Processing City # 146 | mapiripan
# Processing City # 147 | kodiak
# Processing City # 148 | palu
# Processing City # 149 | saldanha
# Processing City # 150 | sampit
# Processing City # 151 | bongandanga
# Processing City # 152 | upernavik
# Processing City # 153 | ahumada
# Processing City # 154 | pemangkat
# Processing City # 155 | diego de almagro
# Processing City # 156 | bhagwantnagar
# Processing City # 157 | vagur
# Processing City # 158 | ancud
# Processing City # 159 | mar del plata
# Processing City # 160 | karasjok
# Processing City # 161 | severo-kurilsk
# Processing City # 162 | fremont
# Processing City # 163 | pierre
# Processing City # 164 | wulanhaote
# Processing City # 165 | attawapiskat
# Processing City # 166 | namibe
# Processing City # 167 | grand river south east
# Processing City # 168 | hofn
# Processing City # 169 | teacapan
# Processing City # 170 | tapes
# Processing City # 171 | buala
# Processing City # 172 | ketchikan
# Processing City # 173 | samusu
# Processing City # 174 | rocha
# Processing City # 175 | coaticook
# Processing City # 176 | zhigalovo
# Processing City # 177 | bengkulu
# Processing City # 178 | loa janan
# Processing City # 179 | karratha
# Processing City # 180 | bathsheba
# Processing City # 181 | aran
# Processing City # 182 | villena
# Processing City # 183 | saint-philippe
# Processing City # 184 | minab
# Processing City # 185 | ballina
# Processing City # 186 | sioux lookout
# Processing City # 187 | the hammocks
# Processing City # 188 | kyra
# Processing City # 189 | fengzhen
# Processing City # 190 | king city
# Processing City # 191 | xining
# Processing City # 192 | lompoc
# Processing City # 193 | morondava
# Processing City # 194 | rawson
# Processing City # 195 | pasighat
# Processing City # 196 | goure
# Processing City # 197 | wadi musa
# Processing City # 198 | nouadhibou
# Processing City # 199 | acapulco
# Processing City # 200 | puerto madero
# Processing City # 201 | hamilton
# Processing City # 202 | puerto del rosario
# Processing City # 203 | havre-saint-pierre
# Processing City # 204 | norman wells
# Processing City # 205 | carnarvon
# Processing City # 206 | east london
# Processing City # 207 | biak
# Processing City # 208 | santa maria
# Processing City # 209 | lorengau
# Processing City # 210 | isla mujeres
# Processing City # 211 | mount gambier
# Processing City # 212 | asosa
# Processing City # 213 | illoqqortoormiut
# Processing City # 214 | primorsko-akhtarsk
# Processing City # 215 | aklavik
# Processing City # 216 | meyungs
# Processing City # 217 | valdemarpils
# Processing City # 218 | sola
# Processing City # 219 | salalah
# Processing City # 220 | kruisfontein
# Processing City # 221 | aranos
# Processing City # 222 | hasaki
# Processing City # 223 | mayor pablo lagerenza
# Processing City # 224 | sorong
# Processing City # 225 | komsomolskiy
# Processing City # 226 | maniitsoq
# Processing City # 227 | khatanga
# Processing City # 228 | launceston
# Processing City # 229 | la palma
# Processing City # 230 | kaitangata
# Processing City # 231 | port macquarie
# Processing City # 232 | sao filipe
# Processing City # 233 | zhob
# Processing City # 234 | maun
# Processing City # 235 | acarau
# Processing City # 236 | kazalinsk
# Processing City # 237 | umzimvubu
# Processing City # 238 | mafinga
# Processing City # 239 | aras
# Processing City # 240 | garagoa
# Processing City # 241 | aiken
# Processing City # 242 | faanui
# Processing City # 243 | kabinda
# Processing City # 244 | isangel
# Processing City # 245 | tashtyp
# Processing City # 246 | contamana
# Processing City # 247 | gat
# Processing City # 248 | inhuma
# Processing City # 249 | mabaruma
# Processing City # 250 | muisne
# Processing City # 251 | candido mendes
# Processing City # 252 | axim
# Processing City # 253 | la ronge
# Processing City # 254 | arraial do cabo
# Processing City # 255 | lloydminster
# Processing City # 256 | ponta delgada
# Processing City # 257 | grindavik
# Processing City # 258 | kita
# Processing City # 259 | hambantota
# Processing City # 260 | luderitz
# Processing City # 261 | pinahat
# Processing City # 262 | rio grande
# Processing City # 263 | broome
# Processing City # 264 | gibsons
# Processing City # 265 | avanigadda
# Processing City # 266 | dharchula
# Processing City # 267 | salekhard
# Processing City # 268 | calama
# Processing City # 269 | pringsewu
# Processing City # 270 | butembo
# Processing City # 271 | yar-sale
# Processing City # 272 | santa isabel do rio negro
# Processing City # 273 | tiquisio
# Processing City # 274 | paamiut
# Processing City # 275 | crixas
# Processing City # 276 | haines junction
# Processing City # 277 | soyo
# Processing City # 278 | anloga
# Processing City # 279 | corrientes
# Processing City # 280 | bajo baudo
# Processing City # 281 | catamarca
# Processing City # 282 | masallatah
# Processing City # 283 | mitu
# Processing City # 284 | hualmay
# Processing City # 285 | ngunguru
# Processing City # 286 | naze
# Processing City # 287 | rantoul
# Processing City # 288 | katsuura
# Processing City # 289 | jalu
# Processing City # 290 | tuktoyaktuk
# Processing City # 291 | iqaluit
# Processing City # 292 | marzuq
# Processing City # 293 | sao joao da barra
# Processing City # 294 | steenwijk
# Processing City # 295 | manta
# Processing City # 296 | villanueva
# Processing City # 297 | dryden
# Processing City # 298 | nome
# Processing City # 299 | gornopravdinsk
# Processing City # 300 | tsaratanana
# Processing City # 301 | vardo
# Processing City # 302 | avera
# Processing City # 303 | viseu
# Processing City # 304 | cabo san lucas
# Processing City # 305 | cherskiy
# Processing City # 306 | khorramshahr
# Processing City # 307 | ust-nera
# Processing City # 308 | mutoko
# Processing City # 309 | mayo
# Processing City # 310 | labuhan
# Processing City # 311 | geraldton
# Processing City # 312 | malaya vishera
# Processing City # 313 | mchinji
# Processing City # 314 | owando
# Processing City # 315 | tessalit
# Processing City # 316 | college
# Processing City # 317 | pryazha
# Processing City # 318 | oranjestad
# Processing City # 319 | starkville
# Processing City # 320 | kralendijk
# Processing City # 321 | tecoanapa
# Processing City # 322 | yangambi
# Processing City # 323 | raudeberg
# Processing City # 324 | rolim de moura
# Processing City # 325 | skibbereen
# Processing City # 326 | husavik
# Processing City # 327 | bilibino
# Processing City # 328 | tiksi
# Processing City # 329 | praia da vitoria
# Processing City # 330 | sur
# Processing City # 331 | boa vista
# Processing City # 332 | naranjal
# Processing City # 333 | moyobamba
# Processing City # 334 | gornyak
# Processing City # 335 | henties bay
# Processing City # 336 | cassilandia
# Processing City # 337 | soure
# Processing City # 338 | somers point
# Processing City # 339 | astana
# Processing City # 340 | saurimo
# Processing City # 341 | wamba
# Processing City # 342 | esperance
# Processing City # 343 | agirish
# Processing City # 344 | kangaba
# Processing City # 345 | acari
# Processing City # 346 | mana
# Processing City # 347 | urambo
# Processing City # 348 | cortez
# Processing City # 349 | tuatapere
# Processing City # 350 | padang
# Processing City # 351 | muchkapskiy
# Processing City # 352 | viligili
# Processing City # 353 | karaul
# Processing City # 354 | simao
# Processing City # 355 | airai
# Processing City # 356 | vaitupu
# Processing City # 357 | yar
# Processing City # 358 | port blair
# Processing City # 359 | peniche
# Processing City # 360 | nishihara
# Processing City # 361 | roald
# Processing City # 362 | sompeta
# Processing City # 363 | bonavista
# Processing City # 364 | yatou
# Processing City # 365 | klaeng
# Processing City # 366 | potam
# Processing City # 367 | hauterive
# Processing City # 368 | clyde river
# Processing City # 369 | pisco
# Processing City # 370 | yeppoon
# Processing City # 371 | pozo colorado
# Processing City # 372 | mogadishu
# Processing City # 373 | rio pardo de minas
# Processing City # 374 | amarante do maranhao
# Processing City # 375 | harbour breton
# Processing City # 376 | kirakira
# Processing City # 377 | coahuayana
# Processing City # 378 | farafangana
# Processing City # 379 | ixtapa
# Processing City # 380 | hede
# Processing City # 381 | vestmannaeyjar
# Processing City # 382 | esso
# Processing City # 383 | sembe
# Processing City # 384 | black river
# Processing City # 385 | tual
# Processing City # 386 | arrifes
# Processing City # 387 | rameshki
# Processing City # 388 | ambon
# Processing City # 389 | morshansk
# Processing City # 390 | abu dhabi
# Processing City # 391 | havoysund
# Processing City # 392 | binga
# Processing City # 393 | punta alta
# Processing City # 394 | san jose de sisa
# Processing City # 395 | anadyr
# Processing City # 396 | nikolskoye
# Processing City # 397 | port augusta
# Processing City # 398 | pindushi
# Processing City # 399 | kaniama
# Processing City # 400 | hobyo
# Processing City # 401 | boke
# Processing City # 402 | chokurdakh
# Processing City # 403 | wake forest
# Processing City # 404 | grand-lahou
# Processing City # 405 | prince rupert
# Processing City # 406 | niquelandia
# Processing City # 407 | shingu
# Processing City # 408 | stulovo
# Processing City # 409 | bandarbeyla
# Processing City # 410 | carutapera
# Processing City # 411 | melk
# Processing City # 412 | surt
# Processing City # 413 | mazatlan
# Processing City # 414 | nago
# Processing City # 415 | mackay
# Processing City # 416 | kenora
# Processing City # 417 | prainha
# Processing City # 418 | nagod
# Processing City # 419 | baker city
# Processing City # 420 | paradwip
# Processing City # 421 | matara
# Processing City # 422 | namatanai
# Processing City # 423 | sfantu gheorghe
# Processing City # 424 | novyy urengoy
# Processing City # 425 | marsh harbour
# Processing City # 426 | romitan
# Processing City # 427 | swellendam
# Processing City # 428 | kuusamo
# Processing City # 429 | savannah bight
# Processing City # 430 | kamenskoye
# Processing City # 431 | rorvik
# Processing City # 432 | houston
# Processing City # 433 | nanortalik
# Processing City # 434 | dawlatabad
# Processing City # 435 | gravdal
# Processing City # 436 | bolshoye soldatskoye
# Processing City # 437 | corinto
# Processing City # 438 | atambua
# Processing City # 439 | derzhavinsk
# Processing City # 440 | petropavlovsk-kamchatskiy
# Processing City # 441 | dimitrovgrad
# Processing City # 442 | anuchino
# Processing City # 443 | bartica
# Processing City # 444 | cap malheureux
# Processing City # 445 | boyuibe
# Processing City # 446 | hami
# Processing City # 447 | kavieng
# Processing City # 448 | itambe
# Processing City # 449 | lavrentiya
# Processing City # 450 | korla
# Processing City # 451 | vestmanna
# Processing City # 452 | kudahuvadhoo
# Processing City # 453 | port hardy
# Processing City # 454 | gimli
# Processing City # 455 | alyangula
# Processing City # 456 | mount isa
# Processing City # 457 | susangerd
# Processing City # 458 | show low
# Processing City # 459 | vitim
# Processing City # 460 | yarensk
# Processing City # 461 | obihiro
# Processing City # 462 | mahebourg
# Processing City # 463 | bereda
# Processing City # 464 | owensboro
# Processing City # 465 | magistralnyy
# Processing City # 466 | roanoke rapids
# Processing City # 467 | yerbogachen
# Processing City # 468 | candawaga
# Processing City # 469 | ahar
# Processing City # 470 | pilot butte
# Processing City # 471 | emerald
# Processing City # 472 | pacific grove
# Processing City # 473 | kotma
# Processing City # 474 | gazanjyk
# Processing City # 475 | ahero
# Processing City # 476 | tsiroanomandidy
# Processing City # 477 | tommot
# Processing City # 478 | mehamn
# Processing City # 479 | arman
# Processing City # 480 | luoyang
# Processing City # 481 | mecca
# Processing City # 482 | labutta
# Processing City # 483 | churapcha
# Processing City # 484 | miandrivazo
# Processing City # 485 | berlevag
# Processing City # 486 | westport
# Processing City # 487 | mankono
# Processing City # 488 | riyadh
# Processing City # 489 | zhoucheng
# Processing City # 490 | noyabrsk
# Processing City # 491 | semikarakorsk
# Processing City # 492 | ilabaya
# Processing City # 493 | guerrero negro
# Processing City # 494 | marcona
# Processing City # 495 | port lincoln
# Processing City # 496 | majene
# Processing City # 497 | victoria
# Processing City # 498 | saleaula
# Processing City # 499 | port hawkesbury
# Processing City # 500 | khandbari
# Processing City # 501 | flinders
# Processing City # 502 | torbay
# Processing City # 503 | taoudenni
# Processing City # 504 | palabuhanratu
# Processing City # 505 | tabou
# Processing City # 506 | port-gentil
# Processing City # 507 | rondonopolis
# Processing City # 508 | verkhnetulomskiy
# Processing City # 509 | turukhansk
# Processing City # 510 | borodyanka
# Processing City # 511 | saint-francois
# Processing City # 512 | monrovia
# Processing City # 513 | velykoploske
# Processing City # 514 | alofi
# Processing City # 515 | yirol
# Processing City # 516 | strezhevoy
# Processing City # 517 | fortuna
# Processing City # 518 | sedona
# Processing City # 519 | dunedin
# Processing City # 520 | spring hill
# Processing City # 521 | kiama
# Processing City # 522 | rio real
# Processing City # 523 | kawalu
# Processing City # 524 | pingliang
# Processing City # 525 | vimperk
# Processing City # 526 | nguiu
# Processing City # 527 | santiago del estero
# Processing City # 528 | verkhoyansk
# Processing City # 529 | kahului
# Processing City # 530 | nassau
# Processing City # 531 | awbari
# Processing City # 532 | sinnamary
# Processing City # 533 | merritt
# Processing City # 534 | puerto carreno
# Processing City # 535 | sobolevo
# Processing City # 536 | alekseyevsk
# Processing City # 537 | kadykchan
# Processing City # 538 | melville
# Processing City # 539 | bayir
# Processing City # 540 | ongole
# Processing City # 541 | inta
# Processing City # 542 | kloulklubed
# Processing City # 543 | ust-ilimsk
# Processing City # 544 | baie du tombeau
# Processing City # 545 | lluta
# Processing City # 546 | yulara
# Processing City # 547 | teya
# Processing City # 548 | los llanos de aridane
# Processing City # 549 | san jose
# Processing City # 550 | bolungarvik
# Processing City # 551 | tomatlan
# Processing City # 552 | sirvintos
# Processing City # 553 | belem de sao francisco
# Processing City # 554 | gazli
# Processing City # 555 | cordoba
# Processing City # 556 | balaghat
# Processing City # 557 | comodoro rivadavia
# Processing City # 558 | salinas
# Processing City # 559 | nara
# Processing City # 560 | laguna beach
# Processing City # 561 | makakilo city
# Processing City # 562 | waipawa
# Processing City # 563 | paucartambo
# Processing City # 564 | vostok
# Processing City # 565 | berdigestyakh
# Processing City # 566 | cerrito
# Processing City # 567 | cabadiangan
# Processing City # 568 | kamina
# Processing City # 569 | meulaboh
# Processing City # 570 | vanimo
# Processing City # 571 | fairbanks
# Processing City # 572 | alamor
# Processing City # 573 | idlib
# Processing City # 574 | yalutorovsk
# Processing City # 575 | montepuez
# Processing City # 576 | jaque
# Processing City # 577 | orlik
# Processing City # 578 | manavalakurichi
# Processing City # 579 | belmonte
# Processing City # 580 | kungurtug
# Processing City # 581 | bolshiye berezniki
# Processing City # 582 | deputatskiy
# Processing City # 583 | soke
# Processing City # 584 | northam
# Processing City # 585 | hare bay
# Processing City # 586 | sistranda
# Processing City # 587 | hammerfest
# Processing City # 588 | wanaka
# Processing City # 589 | gamba
# Processing City # 590 | harper
# Processing City # 591 | antalaha
# Processing City # 592 | chamrajnagar
# Processing City # 593 | senno
# Processing City # 594 | tezu
# Processing City # 595 | vila
# Processing City # 596 | yugorsk
# Processing City # 597 | artigas
# Processing City # 598 | bismarck
# Processing City # 599 | liverpool
# Processing City # 600 | omsukchan
# Processing City # 601 | nizhniy tsasuchey
# Processing City # 602 | rabo de peixe
# Processing City # 603 | tambacounda
# Processing City # 604 | jind
# Processing City # 605 | saint-joseph
# Processing City # 606 | sentyabrskiy
# Processing City # 607 | nuuk
# Processing City # 608 | yenagoa
# Processing City # 609 | awjilah
# Processing City # 610 | selma
# Processing City # 611 | biltine
# Processing City # 612 | okhotsk
# Processing City # 613 | ulaanbaatar
# Processing City # 614 | klungkung
# Processing City # 615 | basco
# Processing City # 616 | ikalamavony
# Processing City # 617 | varhaug
# Processing City # 618 | hay river
# Processing City # 619 | touros
# Processing City # 620 | novyy svit
# Processing City # 621 | clarence town
# ------------------------------------------------------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities=[]
err_count = 0
for city in city_json:
    try:
        city_to_append = {'City': city['name'],
                          'Cloudiness': city['clouds']['all'],
                          'Country': city['sys']['country'],
                          'Date': city['dt'],
                          'Humidity': city['main']['humidity'],
                          'Latitude': city['coord']['lat'],
                          'Longitude': city['coord']['lon'],
                          'Temperature': city['main']['temp_max'],
                          'Wind Speed': city['wind']['speed'] 
                          
                         }
        cities.append(city_to_append)
    except:
        err_count += 1
city_df = pd.DataFrame(cities)
city_df.count()
# Out:
# City           577
# Cloudiness     577
# Country        577
# Date           577
# Humidity       577
# Latitude       577
# Longitude      577
# Temperature    577
# Wind Speed     577
# dtype: int64

# %%
# Export the city data into a .csv.

city_df.to_csv('output_data\weather_by_city.csv', index=False)

# Display the DataFrame
city_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0    Codrington          95      AU  1586653519        62    -38.27
# 1     Busselton          92      AU  1586653602        60    -33.65
# 2  Ponta do Sol          40      PT  1586653602        67     32.67
# 3       Rikitea          49      PF  1586653602        73    -23.12
# 4       Sakakah           0      SA  1586653603        41     29.97
#
#    Longitude  Temperature  Wind Speed
# 0     141.97        55.71        9.84
# 1     115.33        73.99        9.22
# 2     -17.10        62.60       12.75
# 3    -134.97        78.06        4.88
# 4      40.21        59.00        5.88

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ###  Build series of Sctter plots to showcase the following relationships:
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# * After each plot add a sentence or too explaining what the code is and analyzing.

# %% [markdown]
# ### Latitude vs. Temperature Plot
#
# #### This code is analyzing the max temperature of each city and latitude.

# %%
city_df.plot.scatter('Latitude', 'Temperature', alpha=0.5, edgecolors='black')
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (F)')
plt.xlim(-80,100)
plt.ylim(-20, 120)
#plt.ylim(min([Temperature])-20,max([Temperature])+20)
plt.grid()


plt.savefig('output_data\Lat_Vs_Temp.png')

plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot
#
# #### This code is analyzing the humidity of each city and latitude.

# %%
city_df.plot.scatter('Latitude', 'Humidity', alpha=0.5, edgecolors='black')
plt.title(f"City Latitude vs. Humidity ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Humidity (%)')
plt.xlim(-80,100)
plt.ylim(-20, 120)

plt.grid()


plt.savefig('output_data\Lat_Vs_Humidity.png')

plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot
#
# #### This code is analyzing the Cloudiness of each city and latitude.

# %%
city_df.plot.scatter('Latitude', 'Cloudiness', alpha=0.5, edgecolors='black')
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Cloudiness (%)')
plt.xlim(-70,90)
plt.ylim(-10, 110)

plt.grid()


plt.savefig('output_data\Lat_Vs_Cloudiness.png')

plt.show()

# %% [markdown]
# ###  Latitude vs. Wind Speed Plot
#
# #### This code is analyzing the speed of wind of each city and latitude.

# %%
city_df.plot.scatter('Latitude', 'Wind Speed', alpha=0.5, edgecolors='black')
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed (mph')
plt.xlim(-60,90)
plt.ylim(-5, 50)

plt.grid()


plt.savefig('output_data\Lat_Vs_WindSpeed.png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values, alpha=0.5)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    print(f"Equation of regrssion line is: {line_eq}")
    print(f"The correlation is: {rvalue}")
   
    print(f"The r-squared is: {(rvalue)**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_df.loc[city_df["Latitude"] >= 0,:]


northlat_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 2  Ponta do Sol          40      PT  1586653602        67     32.67
# 4       Sakakah           0      SA  1586653603        41     29.97
# 5          Asău          74      RO  1586653453        74     46.43
# 6          Rast          41      RO  1586653603        75     43.88
# 7      Klaksvík         100      FO  1586653603        80     62.23
#
#    Longitude  Temperature  Wind Speed
# 2     -17.10        62.60       12.75
# 4      40.21        59.00        5.88
# 5      26.40        39.00        6.93
# 6      23.28        48.99        6.93
# 7      -6.59        39.20       24.16

# %%
southlat_df = city_df.loc[city_df["Latitude"] < 0,:]
southlat_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0   Codrington          95      AU  1586653519        62    -38.27     141.97
# 1    Busselton          92      AU  1586653602        60    -33.65     115.33
# 3      Rikitea          49      PF  1586653602        73    -23.12    -134.97
# 11      Atuona          38      PF  1586653604        64     -9.80    -139.03
# 13   Cape Town          75      ZA  1586653565        93    -33.93      18.42
#
#     Temperature  Wind Speed
# 0         55.71        9.84
# 1         73.99        9.22
# 3         78.06        4.88
# 11        82.67        5.21
# 13        64.99       21.92

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Temperature"]
plt.title('Temperature Vs. Latitude in Northern Hemisphere')

plot_linear_regression(x_values,y_values,'Temperature (F)',(6,50))

plt.savefig('output_data/NorthLat_Vs.Temperature.png')
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 11-12: malformed \N character escape
# Do no tuse \n... or \N...
# Out:
# Equation of regrssion line is: y = -0.97x + 91.17
# The correlation is: -0.9076201960093645
# The r-squared is: 0.8237744202040772

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Temperature"]
plt.title('Temperature Vs. Southern Latitides')


plot_linear_regression(x_values,y_values,'Temperature (F)',(-50,52))

plt.savefig('output_data/SouthLat_Vs_Temperature.png')
# Out:
# Equation of regrssion line is: y = 0.48x + 80.57
# The correlation is: 0.6660873585910586
# The r-squared is: 0.4436723692748135

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plt.title('Humidity Vs. Latitude in Northern Hemisphere')

plot_linear_regression(x_values,y_values,'Humidity (%)',(6,50))
plt.savefig('output_data/NorthLat_Vs_Humidity.png')
# Out:
# Equation of regrssion line is: y = 0.26x + 56.53
# The correlation is: 0.23289622853492736
# The r-squared is: 0.054240653265793116

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plt.title('Humidity Vs. Latitude in Southern Hemisphere')

plot_linear_regression(x_values,y_values,'Humidity (%)',(-50,50))

plt.savefig('output_data/SouthLat_Vs_Humidity.png')
# Out:
# Equation of regrssion line is: y = 0.38x + 76.72
# The correlation is: 0.30756489934713604
# The r-squared is: 0.09459616731041393

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plt.title('Cloudiness Vs. Latitude in Northern Hemisphere')

plot_linear_regression(x_values,y_values,'Cloudiness (%)',(6,30))

plt.savefig('output_data/NorthLat_Vs_Cloudiness.png')
# Out:
# Equation of regrssion line is: y = 0.15x + 45.04
# The correlation is: 0.0776294697402034
# The r-squared is: 0.006026334572145156

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plt.title('Cloudiness Vs. Latitude in Southern Hemisphere')

plot_linear_regression(x_values,y_values,'Cloudiness (%)',(-50,30))

plt.savefig('output_data/SouthLat_Vs_Cloudiness.png')
# Out:
# Equation of regrssion line is: y = 0.66x + 69.06
# The correlation is: 0.23878689973067266
# The r-squared is: 0.05701918348298632

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plt.title('WindSpeed Vs. Latitude in Northern Hemisphere')

plot_linear_regression(x_values,y_values,'Wind Speed (mph)',(6,18))

plt.savefig('output_data/NorthLat_Vs_WindSpeed.png')
# Out:
# Equation of regrssion line is: y = 0.04x + 7.0
# The correlation is: 0.13728216284812522
# The r-squared is: 0.018846392236259172

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plt.title('WindSpeed Vs. Latitude in Southern Hemisphere')

plot_linear_regression(x_values,y_values,'Wind Speed (mph)',(-50,13))

plt.savefig('output_data\SouthLat_Vs_WindSpeed.png')
# Out:
# Equation of regrssion line is: y = -0.19x + 2.81
# The correlation is: -0.5212168225880787
# The r-squared is: 0.2716669761488127
